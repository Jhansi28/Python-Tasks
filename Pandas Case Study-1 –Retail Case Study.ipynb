# %%
import pandas as pd
import numpy as np

# %%
customer = pd.read_csv("C:/Users/Latha/Desktop/Pandas case stud y3/Customer.csv")

# %%
customer.head()
# Out:
#    customer_Id         DOB Gender  city_code
# 0       268408  02-01-1970      M        4.0
# 1       269696  07-01-1970      F        8.0
# 2       268159  08-01-1970      F        8.0
# 3       270181  10-01-1970      F        2.0
# 4       268073  11-01-1970      M        1.0

# %%
customer.shape
# Out:
# (5647, 4)

# %%
customer.columns.values
# Out:
# array(['customer_Id', 'DOB', 'Gender', 'city_code'], dtype=object)

# %%
 customer['cust_id'] = customer['customer_Id']

# %%
customer.drop(['customer_Id'], axis = 1, inplace = True)

# %%
customer[['cust_id', 'DOB', 'Gender', 'city_code']]
# Out:
#       cust_id         DOB Gender  city_code
# 0      268408  02-01-1970      M        4.0
# 1      269696  07-01-1970      F        8.0
# 2      268159  08-01-1970      F        8.0
# 3      270181  10-01-1970      F        2.0
# 4      268073  11-01-1970      M        1.0
# 5      273216  15-01-1970      F        5.0
# 6      266929  15-01-1970      M        8.0
# 7      275152  16-01-1970      M        4.0
# 8      275034  18-01-1970      F        4.0
# 9      273966  21-01-1970      M        8.0
# 10     270829  22-01-1970      F        8.0
# 11     266997  23-01-1970      M        9.0
# 12     272455  25-01-1970      M        7.0
# 13     274593  26-01-1970      M       10.0
# 14     273391  29-01-1970      F        2.0
# 15     267657  29-01-1970      F        7.0
# 16     271344  29-01-1970      F        5.0
# 17     268275  01-02-1970      F        7.0
# 18     274630  01-02-1970      M        4.0
# 19     273541  01-02-1970      M        4.0
# ...

# %%
total = customer.groupby(['cust_id']).nunique()

# %%
total.count()
# Out:
# DOB          5647
# Gender       5647
# city_code    5647
# cust_id      5647
# dtype: int64

# %%
customer.head()
# Out:
#           DOB Gender  city_code  cust_id
# 0  02-01-1970      M        4.0   268408
# 1  07-01-1970      F        8.0   269696
# 2  08-01-1970      F        8.0   268159
# 3  10-01-1970      F        2.0   270181
# 4  11-01-1970      M        1.0   268073

# %%
customer['cust_id'].count()
# Out:
# 5647

# %%
customer.shape
# Out:
# (5647, 4)

# %%
5506-5647
# Out:
# -141

# %%
transactions = pd.read_csv("C:/Users/Latha/Desktop/Pandas case stud y3/Transactions.csv")

# %%
transactions.head(10)
# Out:
#    transaction_id  cust_id   tran_date  prod_subcat_code  prod_cat_code  Qty  \
# 0     80712190438   270351  28-02-2014                 1              1   -5
# 1     29258453508   270384  27-02-2014                 5              3   -5
# 2     51750724947   273420  24-02-2014                 6              5   -2
# 3     93274880719   271509  24-02-2014                11              6   -3
# 4     51750724947   273420  23-02-2014                 6              5   -2
# 5     97439039119   272357  23-02-2014                 8              3   -2
# 6     45649838090   273667  22-02-2014                11              6   -1
# 7     22643667930   271489  22-02-2014                12              6   -1
# 8     79792372943   275108  22-02-2014                 3              1   -3
# 9     50076728598   269014  21-02-2014                 8              3   -4
#
#    Rate      Tax  total_amt Store_type
# 0  -772  405.300  -4265.300     e-Shop
# 1 -1497  785.925  -8270.925     e-Shop
# ...

# %%
transactions.shape
# Out:
# (23053, 10)

# %%
transactions['cust_id'].count()
# Out:
# 23053

# %%
data = transactions.groupby(['cust_id']).nunique()

# %%
data.count()
# Out:
# transaction_id      5506
# cust_id             5506
# tran_date           5506
# prod_subcat_code    5506
# prod_cat_code       5506
# Qty                 5506
# Rate                5506
# Tax                 5506
# total_amt           5506
# Store_type          5506
# dtype: int64

# %%
# df_new = pd.concat([customer, transactions], sort = False, ignore_index=True)

# %%
df_new = pd.merge(customer, transactions, left_on='cust_id', right_on='cust_id')

# %%
df_new.loc[df_new['cust_id'] == 268408].count()
# Out:
# DOB                 11
# Gender              11
# city_code           11
# cust_id             11
# transaction_id      11
# tran_date           11
# prod_subcat_code    11
# prod_cat_code       11
# Qty                 11
# Rate                11
# Tax                 11
# total_amt           11
# Store_type          11
# dtype: int64

# %%
n = df_new.groupby(['cust_id']).nunique()

# %%
n.count()
# Out:
# DOB                 5506
# Gender              5506
# city_code           5506
# cust_id             5506
# transaction_id      5506
# tran_date           5506
# prod_subcat_code    5506
# prod_cat_code       5506
# Qty                 5506
# Rate                5506
# Tax                 5506
# total_amt           5506
# Store_type          5506
# dtype: int64

# %%
final = pd.merge(new_df, df_b, on='subject_id', how='left')

# %%
product = pd.read_csv("C:/Users/Latha/Desktop/Pandas case stud y3/prod_cat_info.csv")

# %%
product
# Out:
#     prod_cat_code          prod_cat  prod_sub_cat_code          prod_subcat
# 0               1          Clothing                  4                 Mens
# 1               1          Clothing                  1                Women
# 2               1          Clothing                  3                 Kids
# 3               2          Footwear                  1                 Mens
# 4               2          Footwear                  3                Women
# 5               2          Footwear                  4                 Kids
# 6               3       Electronics                  4              Mobiles
# 7               3       Electronics                  5            Computers
# 8               3       Electronics                  8  Personal Appliances
# 9               3       Electronics                  9              Cameras
# 10              3       Electronics                 10      Audio and video
# ...

# %%
product['prod_subcat_code']= product['prod_sub_cat_code'] 
product
# Out:
#     prod_cat_code          prod_cat  prod_sub_cat_code          prod_subcat  \
# 0               1          Clothing                  4                 Mens
# 1               1          Clothing                  1                Women
# 2               1          Clothing                  3                 Kids
# 3               2          Footwear                  1                 Mens
# 4               2          Footwear                  3                Women
# 5               2          Footwear                  4                 Kids
# 6               3       Electronics                  4              Mobiles
# 7               3       Electronics                  5            Computers
# 8               3       Electronics                  8  Personal Appliances
# 9               3       Electronics                  9              Cameras
# 10              3       Electronics                 10      Audio and video
# ...

# %%
product.drop(['prod_sub_cat_code'], axis = 1, inplace = True)

# %%
product = product[['prod_cat_code', 'prod_cat', 'prod_subcat_code','prod_subcat']]

# %%
product.head()
# Out:
#    prod_cat_code  prod_cat  prod_subcat_code prod_subcat
# 0              1  Clothing                 4        Mens
# 1              1  Clothing                 1       Women
# 2              1  Clothing                 3        Kids
# 3              2  Footwear                 1        Mens
# 4              2  Footwear                 3       Women

# %%
# customer_final = pd.merge(transactions, product, on=['prod_cat_code', 'prod_subcat_code'], how='outer')

# %%
# customer_final.shape
# Out:
# (23053, 12)

# %%
# customer_final.dtypes
# Out:
# transaction_id        int64
# cust_id               int64
# tran_date            object
# prod_subcat_code      int64
# prod_cat_code         int64
# Qty                   int64
# Rate                  int64
# Tax                 float64
# total_amt           float64
# Store_type           object
# prod_cat             object
# prod_subcat          object
# dtype: object

# %%
cross_tab_details = pd.crosstab(customer_final.prod_cat, customer_final.prod_subcat,margins=True)

# %%
cross_tab_details
# Out:
# prod_subcat       Academic  Audio and video  Bath  Cameras  Children  Comics  \
# prod_cat
# Bags                     0                0     0        0         0       0
# Books                  967                0     0        0      1035    1031
# Clothing                 0                0     0        0         0       0
# Electronics              0              952     0      985         0       0
# Footwear                 0                0     0        0         0       0
# Home and kitchen         0                0  1023        0         0       0
# All                    967              952  1023      985      1035    1031
#
# prod_subcat       Computers  DIY  Fiction  Furnishing  Kids  Kitchen  Mens  \
# prod_cat
# Bags                      0    0        0           0     0        0  1003
# Books                     0  989     1043           0     0        0     0
# Clothing                  0    0        0           0   988        0   967
# ...

# %%
cdetails = pd.crosstab(customer_final.prod_subcat, customer_final.prod_cat)
cdetails
# Out:
# prod_cat             Bags  Books  Clothing  Electronics  Footwear  \
# prod_subcat
# Academic                0    967         0            0         0
# Audio and video         0      0         0          952         0
# Bath                    0      0         0            0         0
# Cameras                 0      0         0          985         0
# Children                0   1035         0            0         0
# Comics                  0   1031         0            0         0
# Computers               0      0         0          958         0
# DIY                     0    989         0            0         0
# Fiction                 0   1043         0            0         0
# Furnishing              0      0         0            0         0
# Kids                    0      0       988            0      1009
# Kitchen                 0      0         0            0         0
# Mens                 1003      0       967            0       942
# ...

# %%
customer_final.groupby(['Store_type']).count()
# Out:
#                 transaction_id  cust_id  tran_date  prod_subcat_code  \
# Store_type
# Flagship store            4577     4577       4577              4577
# MBR                       4661     4661       4661              4661
# TeleShop                  4504     4504       4504              4504
# e-Shop                    9311     9311       9311              9311
#
#                 prod_cat_code   Qty  Rate   Tax  total_amt  prod_cat  \
# Store_type
# Flagship store           4577  4577  4577  4577       4577      4577
# MBR                      4661  4661  4661  4661       4661      4661
# TeleShop                 4504  4504  4504  4504       4504      4504
# e-Shop                   9311  9311  9311  9311       9311      9311
#
#                 prod_subcat
# Store_type
# Flagship store         4577
# MBR                    4661
# TeleShop               4504
# e-Shop                 9311

# %%
crosstab3 = pd.crosstab([customer_final.prod_cat, customer_final.prod_subcat],customer_final.Store_type, margins=True)
crosstab3
# Out:
# Store_type                            Flagship store   MBR  TeleShop  e-Shop  \
# prod_cat         prod_subcat
# Bags             Mens                            193   204       213     393
#                  Women                           196   214       197     388
# Books            Academic                        185   206       182     394
#                  Children                        233   182       197     423
#                  Comics                          192   211       210     418
#                  DIY                             189   205       206     389
#                  Fiction                         206   198       214     425
#                  Non-Fiction                     218   222       166     398
# Clothing         Kids                            188   212       213     375
#                  Mens                            196   188       181     402
#                  Women                           200   226       182     397
# ...

# %%
tax = customer_final['Tax']

# %%
import matplotlib.pyplot as plt
plt.hist(tax, color=['orange'])
# Out:
# (array([4868., 5303., 3023., 2944., 1912., 1823., 1078., 1058.,  523.,
#          521.]),
#  array([  7.35 ,  85.365, 163.38 , 241.395, 319.41 , 397.425, 475.44 ,
#         553.455, 631.47 , 709.485, 787.5  ]),
#  <a list of 10 Patch objects>)

# %%
amount = customer_final['total_amt']
plt.hist(amount, color=['green'])
# Out:
# (array([ 109.,  231.,  360.,  564.,  913., 9062., 5505., 3435., 1930.,
#          944.]),
#  array([-8270.925 , -6615.0825, -4959.24  , -3303.3975, -1647.555 ,
#             8.2875,  1664.13  ,  3319.9725,  4975.815 ,  6631.6575,
#          8287.5   ]),
#  <a list of 10 Patch objects>)

# %%
rate = customer_final['Rate']
plt.hist(rate, color=['brown'])
# Out:
# (array([ 496.,  446.,  464.,  411.,  360., 3413., 4335., 4336., 4349.,
#         4443.]),
#  array([-1.4990e+03, -1.1991e+03, -8.9920e+02, -5.9930e+02, -2.9940e+02,
#          5.0000e-01,  3.0040e+02,  6.0030e+02,  9.0020e+02,  1.2001e+03,
#          1.5000e+03]),
#  <a list of 10 Patch objects>)

# %%
cat = customer_final.groupby(by="prod_cat")[["prod_cat"]].count().add_prefix("CountOf_").reset_index()
cat
# Out:
#            prod_cat  CountOf_prod_cat
# 0              Bags              1998
# 1             Books              6069
# 2          Clothing              2960
# 3       Electronics              4898
# 4          Footwear              2999
# 5  Home and kitchen              4129

# %%
cat.plot(kind="bar")
plt.ylabel("Counts")
plt.show()

# %%
sub_cat = customer_final.groupby(by="prod_subcat")[["prod_subcat"]].count().add_prefix("CountOf_").reset_index()
sub_cat
# Out:
#             prod_subcat  CountOf_prod_subcat
# 0              Academic                  967
# 1       Audio and video                  952
# 2                  Bath                 1023
# 3               Cameras                  985
# 4              Children                 1035
# 5                Comics                 1031
# 6             Computers                  958
# 7                   DIY                  989
# 8               Fiction                 1043
# 9            Furnishing                 1007
# 10                 Kids                 1997
# 11              Kitchen                 1037
# 12                 Mens                 2912
# 13              Mobiles                 1031
# 14          Non-Fiction                 1004
# 15  Personal Appliances                  972
# 16                Tools                 1062
# 17                Women                 3048

# %%
sub_cat.plot(kind="bar", color="tomato")
plt.ylabel("Counts")
plt.xlabel("Types")
plt.show()

# %%
store = customer_final.groupby(by="Store_type")[["Store_type"]].count().add_prefix("CountOf_").reset_index()
store
# Out:
#        Store_type  CountOf_Store_type
# 0  Flagship store                4577
# 1             MBR                4661
# 2        TeleShop                4504
# 3          e-Shop                9311

# %%
store.plot(kind="bar", color="pink")
plt.ylabel("Counts")
plt.xlabel("Types")
plt.show()

# %%
transactions.dtypes
# Out:
# transaction_id        int64
# cust_id               int64
# tran_date            object
# prod_subcat_code      int64
# prod_cat_code         int64
# Qty                   int64
# Rate                  int64
# Tax                 float64
# total_amt           float64
# Store_type           object
# dtype: object

# %%
transactions['tran_date'] = pd.to_datetime(transactions['tran_date'])

# %%
transactions.dtypes
# Out:
# transaction_id               int64
# cust_id                      int64
# tran_date           datetime64[ns]
# prod_subcat_code             int64
# prod_cat_code                int64
# Qty                          int64
# Rate                         int64
# Tax                        float64
# total_amt                  float64
# Store_type                  object
# dtype: object

# %%
max(customer_final['tran_date'])
# Out:
# '9/9/2013'

# %%
less = customer_final.loc[customer_final['Rate'] < 0].count()

# %%
less
# Out:
# transaction_id      2177
# cust_id             2177
# tran_date           2177
# prod_subcat_code    2177
# prod_cat_code       2177
# Qty                 2177
# Rate                2177
# Tax                 2177
# total_amt           2177
# Store_type          2177
# prod_cat            2177
# prod_subcat         2177
# dtype: int64

# %%
df_new.head()
# Out:
#           DOB Gender  city_code  cust_id  transaction_id   tran_date  \
# 0  02-01-1970      M        4.0   268408     87243835584  13-01-2014
# 1  02-01-1970      M        4.0   268408     16197868036  16-12-2013
# 2  02-01-1970      M        4.0   268408     16197868036  12/12/2013
# 3  02-01-1970      M        4.0   268408     28810141075    2/9/2013
# 4  02-01-1970      M        4.0   268408     64633435931    6/5/2013
#
#    prod_subcat_code  prod_cat_code  Qty  Rate      Tax  total_amt  \
# 0                 7              5    5   187   98.175   1033.175
# 1                 1              4   -5  -210  110.250  -1160.250
# 2                 1              4    5   210  110.250   1160.250
# 3                10              6    2   813  170.730   1796.730
# 4                 4              2    3   312   98.280   1034.280
#
#        Store_type
# 0        TeleShop
# 1  Flagship store
# 2  Flagship store
# 3        TeleShop
# 4  Flagship store

# %%
product.head()
# Out:
#    prod_cat_code  prod_cat  prod_subcat_code prod_subcat
# 0              1  Clothing                 4        Mens
# 1              1  Clothing                 1       Women
# 2              1  Clothing                 3        Kids
# 3              2  Footwear                 1        Mens
# 4              2  Footwear                 3       Women

# %%
Customer_Final = pd.merge(df_new, product, on=['prod_cat_code', 'prod_subcat_code'], how='outer')

# %%
Customer_Final.head()
# Out:
#           DOB Gender  city_code  cust_id  transaction_id   tran_date  \
# 0  02-01-1970      M        4.0   268408     87243835584  13-01-2014
# 1  16-01-1970      M        4.0   275152     73109425404  25-03-2011
# 2  18-01-1970      F        4.0   275034     64777271023  23-05-2011
# 3  22-01-1970      F        8.0   270829     87174343938   9/12/2013
# 4  29-01-1970      F        7.0   267657     76242744953  23-05-2013
#
#    prod_subcat_code  prod_cat_code  Qty  Rate      Tax  total_amt  \
# 0                 7              5    5   187   98.175   1033.175
# 1                 7              5    2   464   97.440   1025.440
# 2                 7              5    2   197   41.370    435.370
# 3                 7              5    4  1141  479.220   5043.220
# 4                 7              5    4  1020  428.400   4508.400
#
#        Store_type prod_cat prod_subcat
# 0        TeleShop    Books     Fiction
# 1          e-Shop    Books     Fiction
# ...

# %%
Customer_Final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23053 entries, 0 to 23052
# Data columns (total 15 columns):
# DOB                 23053 non-null object
# Gender              23044 non-null object
# city_code           23045 non-null float64
# cust_id             23053 non-null int64
# transaction_id      23053 non-null int64
# tran_date           23053 non-null object
# prod_subcat_code    23053 non-null int64
# prod_cat_code       23053 non-null int64
# Qty                 23053 non-null int64
# Rate                23053 non-null int64
# Tax                 23053 non-null float64
# total_amt           23053 non-null float64
# Store_type          23053 non-null object
# prod_cat            23053 non-null object
# prod_subcat         23053 non-null object
# dtypes: float64(3), int64(6), object(6)
# memory usage: 2.8+ MB

# %%
def Change_type(x):
    x=x.pd.to_datetime()
    return x
data_new=data_new.apply(missing_treat)

# %%
Customer_Final['DOB'] = pd.to_datetime(Customer_Final['DOB'])

# %%
Customer_Final['tran_date'] = pd.to_datetime(Customer_Final['tran_date'])

# %%
Customer_Final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23053 entries, 0 to 23052
# Data columns (total 15 columns):
# DOB                 23053 non-null datetime64[ns]
# Gender              23044 non-null object
# city_code           23045 non-null float64
# cust_id             23053 non-null int64
# transaction_id      23053 non-null int64
# tran_date           23053 non-null datetime64[ns]
# prod_subcat_code    23053 non-null int64
# prod_cat_code       23053 non-null int64
# Qty                 23053 non-null int64
# Rate                23053 non-null int64
# Tax                 23053 non-null float64
# total_amt           23053 non-null float64
# Store_type          23053 non-null object
# prod_cat            23053 non-null object
# prod_subcat         23053 non-null object
# dtypes: datetime64[ns](2), float64(3), int64(6), object(4)
# memory usage: 2.8+ MB

# %%
Customer_Final.head(10)
# Out:
#           DOB Gender  city_code  cust_id  transaction_id   tran_date  \
# 0  02-01-1970      M        4.0   268408     87243835584  13-01-2014
# 1  16-01-1970      M        4.0   275152     73109425404  25-03-2011
# 2  18-01-1970      F        4.0   275034     64777271023  23-05-2011
# 3  22-01-1970      F        8.0   270829     87174343938   9/12/2013
# 4  29-01-1970      F        7.0   267657     76242744953  23-05-2013
# 5  01-02-1970      M        4.0   274630     78357345891   11/4/2012
# 6  01-02-1970      M        4.0   273541     23916816961    9/2/2013
# 7  13-02-1970      F        6.0   269008     35560569829    9/3/2013
# 8  13-02-1970      F        6.0   269008     94033312891  26-04-2012
# 9  14-02-1970    NaN        2.0   267199     56749259881   11/1/2012
#
#    prod_subcat_code  prod_cat_code  Qty  Rate      Tax  total_amt  \
# 0                 7              5    5   187   98.175   1033.175
# 1                 7              5    2   464   97.440   1025.440
# ...

# %%
Customer_Final.tail(10)
# Out:
#               DOB Gender  city_code  cust_id  transaction_id   tran_date  \
# 23043  15-11-1992      F        3.0   268914      1407823655   10/6/2011
# 23044  17-11-1992      M        9.0   269519     29719500605  24-12-2013
# 23045  25-11-1992      F        1.0   273524     25762805863  19-11-2012
# 23046  02-12-1992      F       10.0   272141     71337087467  22-07-2012
# 23047  02-12-1992      F       10.0   272141     71337087467  16-07-2012
# 23048  04-12-1992      F        1.0   267812     63540378797  10/10/2012
# 23049  09-12-1992      F        7.0   274618     71793203305  17-08-2013
# 23050  15-12-1992      F        7.0   268097     91217108818    1/2/2012
# 23051  15-12-1992      F        7.0   268097     90114483354  31-01-2011
# 23052  15-12-1992      F        7.0   268097     90114483354  26-01-2011
#
#        prod_subcat_code  prod_cat_code  Qty  Rate      Tax  total_amt  \
# 23043                10              5    1  1252  131.460   1383.460
# ...

# %%
Customer_Final.describe()
# Out:
#           city_code        cust_id  transaction_id  prod_subcat_code  \
# count  23045.000000   23053.000000    2.305300e+04      23053.000000
# mean       5.482534  271021.746497    5.007348e+10          6.149091
# std        2.863499    2431.692059    2.898194e+10          3.726372
# min        1.000000  266783.000000    3.268991e+06          1.000000
# 25%        3.000000  268935.000000    2.493864e+10          3.000000
# 50%        5.000000  270980.000000    5.009313e+10          5.000000
# 75%        8.000000  273114.000000    7.533000e+10         10.000000
# max       10.000000  275265.000000    9.998755e+10         12.000000
#
#        prod_cat_code           Qty          Rate           Tax     total_amt
# count   23053.000000  23053.000000  23053.000000  23053.000000  23053.000000
# mean        3.763632      2.432395    636.369713    248.667192   2107.308002
# std         1.677016      2.268406    622.363498    187.177773   2507.561264
# ...

# %%
Customer_Final.

# %%
Freq = Customer_Final.select_dtypes(exclude=['int', 'float']).columns
Freq
# Out:
# Index(['DOB', 'Gender', 'cust_id', 'transaction_id', 'tran_date',
#        'prod_subcat_code', 'prod_cat_code', 'Qty', 'Rate', 'Store_type',
#        'prod_cat', 'prod_subcat'],
#       dtype='object')

# %%
cat_var = [key for key in dict(Customer_Final.dtypes)
             if dict(Customer_Final.dtypes)[key] in ['object'] ]
cat_var
# Out:
# ['Gender', 'Store_type', 'prod_cat', 'prod_subcat']

# %%
def freq_tab(x):
    x=x.value_counts()
    return x
cat_var=cat_var.apply(freq_tab)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-61-6fe1b2fa7bfc> in <module>
#       2     x=x.value_counts()
#       3     return x
# ----> 4 cat_var=cat_var.apply(freq_tab)
#
# AttributeError: 'list' object has no attribute 'apply'

# %%
cat_freq_tab = []
for x in cat_var:
    x=x.count()
print(x)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-67-683132db5cbc> in <module>
#       1 cat_freq_tab = []
#       2 for x in cat_var:
# ----> 3     x=x.count()
#       4 print(x)
#
# TypeError: count() takes at least 1 argument (0 given)

# %%
cross_tab_details1 = pd.crosstab(Customer_Final.prod_cat, Customer_Final.Gender,margins=True)
cross_tab_details1
# Out:
# Gender                F      M    All
# prod_cat
# Bags                994   1004   1998
# Books              2949   3116   6065
# Clothing           1439   1518   2957
# Electronics        2328   2570   4898
# Footwear           1529   1469   2998
# Home and kitchen   1994   2134   4128
# All               11233  11811  23044

# %%
Customer_Final.groupby(['prod_cat','Gender'])[['Gender']].count()
# Out:
#                          Gender
# prod_cat         Gender
# Bags             F          994
#                  M         1004
# Books            F         2949
#                  M         3116
# Clothing         F         1439
#                  M         1518
# Electronics      F         2328
#                  M         2570
# Footwear         F         1529
#                  M         1469
# Home and kitchen F         1994
#                  M         2134

# %% [raw]
# "Book" product category is famous amongst Male & Female Categories

# %%
Max_Customer_City = pd.crosstab(Customer_Final.city_code, Customer_Final.Gender,margins=True)

# %%
Max_Customer_City
# Out:
# Gender         F      M    All
# city_code
# 1.0         1186   1072   2258
# 2.0         1061   1204   2265
# 3.0         1082   1329   2411
# 4.0         1142   1280   2422
# 5.0         1156   1204   2360
# 6.0         1050   1073   2123
# 7.0         1252   1104   2356
# 8.0          940   1390   2330
# 9.0         1131   1047   2178
# 10.0        1231   1102   2333
# All        11231  11805  23036

# %%
Customer_Final.groupby(['city_code','Gender'])[['Gender']].count()
# Out:
#                   Gender
# city_code Gender
# 1.0       F         1186
#           M         1072
# 2.0       F         1061
#           M         1204
# 3.0       F         1082
#           M         1329
# 4.0       F         1142
#           M         1280
# 5.0       F         1156
#           M         1204
# 6.0       F         1050
#           M         1073
# 7.0       F         1252
#           M         1104
# 8.0       F          940
#           M         1390
# 9.0       F         1131
#           M         1047
# 10.0      F         1231
#           M         1102

# %% [raw]
# City code ' 4' has the maximum number of customers base

# %%
City = Customer_Final.loc[Customer_Final['city_code'] == 4].count()
City
# Out:
# DOB                 2422
# Gender              2422
# city_code           2422
# cust_id             2422
# transaction_id      2422
# tran_date           2422
# prod_subcat_code    2422
# prod_cat_code       2422
# Qty                 2422
# Rate                2422
# Tax                 2422
# total_amt           2422
# Store_type          2422
# prod_cat            2422
# prod_subcat         2422
# dtype: int64

# %%
Percentage_of_Citycode = (2422/23036)*100
# Out:
# 10.513978121201598

# %% [raw]
# 10.51 percentage constitutes the total no of customers from the city '4'

# %%
Customer_Final['Store_type'].value_counts()
# Out:
# e-Shop            9311
# MBR               4661
# Flagship store    4577
# TeleShop          4504
# Name: Store_type, dtype: int64

# %%
Max_Products = pd.crosstab(Customer_Final.Store_type, Customer_Final.Gender,margins=True)
Max_Products
# Out:
# Gender              F      M    All
# Store_type
# Flagship store   2264   2313   4577
# MBR              2264   2395   4659
# TeleShop         2147   2353   4500
# e-Shop           4558   4750   9308
# All             11233  11811  23044

# %%
Customer_Final.groupby(['Store_type','Gender'])[['Gender']].count()
# Out:
#                        Gender
# Store_type     Gender
# Flagship store F         2264
#                M         2313
# MBR            F         2264
#                M         2395
# TeleShop       F         2147
#                M         2353
# e-Shop         F         4558
#                M         4750

# %%
Customer_Final.groupby('Store_type')[['Store_type']].count()
# Out:
#                 Store_type
# Store_type
# Flagship store        4577
# MBR                   4661
# TeleShop              4504
# e-Shop                9311

# %%
Max_Customer_Qty = pd.crosstab(Customer_Final.Store_type, Customer_Final.Qty,margins=True)
Max_Customer_Qty
# Out:
# Qty              -5   -4   -3   -2   -1     1     2     3     4     5    All
# Store_type
# Flagship store   94   86   87   87   78   831   797   877   796   844   4577
# MBR             113   80   75   94   89   858   858   797   869   828   4661
# TeleShop         76   92   79   91   74   830   840   812   771   839   4504
# e-Shop          174  200  164  166  178  1695  1628  1688  1670  1748   9311
# All             457  458  405  438  419  4214  4123  4174  4106  4259  23053

# %%
Max_Customer_Qty1 = pd.crosstab( Customer_Final.Qty, Customer_Final.Store_type, margins=True)
Max_Customer_Qty1
# Out:
# Store_type  Flagship store   MBR  TeleShop  e-Shop    All
# Qty
# -5                      94   113        76     174    457
# -4                      86    80        92     200    458
# -3                      87    75        79     164    405
# -2                      87    94        91     166    438
# -1                      78    89        74     178    419
# 1                      831   858       830    1695   4214
# 2                      797   858       840    1628   4123
# 3                      877   797       812    1688   4174
# 4                      796   869       771    1670   4106
# 5                      844   828       839    1748   4259
# All                   4577  4661      4504    9311  23053

# %% [raw]
# e-Shop sells the maximum products by value & quantity

# %%
Answer8 = pd.crosstab([Customer_Final.Store_type, Customer_Final.prod_cat],Customer_Final.total_amt, margins=True)
Answer8
# Out:
# total_amt                        -8270.925  -8160.425  -8154.9  -8143.85  \
# Store_type     prod_cat
# Flagship store Bags                      0          0        0         0
#                Books                     0          0        0         0
#                Clothing                  0          0        1         1
#                Electronics               0          0        0         0
#                Footwear                  0          0        0         0
#                Home and kitchen          0          0        0         0
# MBR            Bags                      0          0        0         0
#                Books                     0          0        0         0
#                Clothing                  0          0        0         0
#                Electronics               0          0        0         0
#                Footwear                  0          0        0         0
# ...

# %%
Cost_FlagshipStores = Customer_Final.groupby(by=['Store_type','prod_cat']).count()

# %%
Cost_FlagshipStores
# Out:
#                                   DOB  Gender  city_code  cust_id  \
# Store_type     prod_cat
# Flagship store Bags               389     389        388      389
#                Books             1223    1223       1223     1223
#                Clothing           584     584        584      584
#                Electronics        996     996        995      996
#                Footwear           574     574        574      574
#                Home and kitchen   811     811        811      811
# MBR            Bags               418     418        418      418
#                Books             1224    1223       1224     1224
#                Clothing           626     626        626      626
#                Electronics        953     953        953      953
#                Footwear           609     608        609      609
#                Home and kitchen   831     831        831      831
# TeleShop       Bags               410     410        410      410
# ...

# %%
Customer_Final
# Out:
#               DOB Gender  city_code  cust_id  transaction_id   tran_date  \
# 0      02-01-1970      M        4.0   268408     87243835584  13-01-2014
# 1      16-01-1970      M        4.0   275152     73109425404  25-03-2011
# 2      18-01-1970      F        4.0   275034     64777271023  23-05-2011
# 3      22-01-1970      F        8.0   270829     87174343938   9/12/2013
# 4      29-01-1970      F        7.0   267657     76242744953  23-05-2013
# 5      01-02-1970      M        4.0   274630     78357345891   11/4/2012
# 6      01-02-1970      M        4.0   273541     23916816961    9/2/2013
# 7      13-02-1970      F        6.0   269008     35560569829    9/3/2013
# 8      13-02-1970      F        6.0   269008     94033312891  26-04-2012
# 9      14-02-1970    NaN        2.0   267199     56749259881   11/1/2012
# 10     19-02-1970      M        5.0   272883     35308880657   1/12/2013
# 11     19-02-1970      M        5.0   272883     35308880657  26-11-2013
# ...

# %%
Customer_Final.loc[['Store_type']]
#City = Customer_Final.loc[Customer_Final['city_code'] == 4].count()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-224-e6bda178685d> in <module>
# ----> 1 Customer_Final.loc[['Store_type']]
#       2 #City = Customer_Final.loc[Customer_Final['city_code'] == 4].count()
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1498
#    1499             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1500             return self._getitem_axis(maybe_callable, axis=axis)
#    1501
#    1502     def _is_scalar_access(self, key):
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1900                     raise ValueError('Cannot index with multidimensional key')
#    1901
# -> 1902                 return self._getitem_iterable(key, axis=axis)
#    1903
#    1904             # nested tuple slicing
#
# ...

# %%
#df.loc[(df.Location=='Kolkata') & (df.OwnStore==1),]

Calcuation = Customer_Final.loc[(Customer_Final.prod_cat == 'Electronics') & (Customer_Final.Gender == 'M'),]
Calcuation
# Out:
#               DOB Gender  city_code  cust_id  transaction_id   tran_date  \
# 4092   02-01-1970      M        4.0   268408     56902862040  30-01-2013
# 4095   01-02-1970      M        4.0   274630     78531093747  14-07-2011
# 4097   19-02-1970      M        4.0   272359     81379370831   1/12/2011
# 4099   07-03-1970      M        5.0   271692     54391762918    6/1/2014
# 4100   27-03-1970      M       10.0   270986     14352737996    1/6/2012
# 4102   03-05-1970      M        1.0   272555     97199743948  17-11-2011
# 4103   15-05-1970      M        7.0   267386     47523844726  24-03-2011
# 4107   19-06-1970      M        8.0   273162     68867970973  13-11-2011
# 4109   14-07-1970      M        NaN   268447     50093131361    3/5/2013
# 4110   23-07-1970      M        8.0   267042     51197645157  24-06-2011
# 4111   02-08-1970      M        5.0   267280     49670527288  26-05-2012
# 4121   16-10-1970      M        6.0   270619     42609847505    4/5/2012
# ...

# %%
answer9 = Calcuation[['total_amt']].sum()

# %%
answer9
# Out:
# total_amt    5703109.425
# dtype: float64

# %% [raw]
# the total amount earned from "Male" customers under the "Electronics" category is $5703109.425

# %%
Customer_Final.to_csv('C:/Users/Latha/Desktop/Pandas case stud y3/out.csv')

# %%
non_zero = customer_final.loc[customer_final['total_amt'] > 0,]
non_zero
# Out:
#        transaction_id  cust_id   tran_date  prod_subcat_code  prod_cat_code  \
# 1         80712190438   270351  20-02-2014                 1              1
# 2         73713102191   268867  15-02-2014                 1              1
# 3         57134739558   270625  14-02-2014                 1              1
# 4         79536458466   271944   12/2/2014                 1              1
# 6         54730601969   274917    7/2/2014                 1              1
# 7         51473331806   267794    5/2/2014                 1              1
# 9         92456150942   267489    3/2/2014                 1              1
# 10        11824708239   274999    2/2/2014                 1              1
# 11        54450927619   271534    2/2/2014                 1              1
# 12        82379417230   269090    1/2/2014                 1              1
# 13        22826695874   270949  31-01-2014                 1              1
# ...

# %%
Customer_Final.dtypes
# Out:
# DOB                 datetime64[ns]
# Gender                      object
# city_code                  float64
# cust_id                      int64
# transaction_id               int64
# tran_date                   object
# prod_subcat_code             int64
# prod_cat_code                int64
# Qty                          int64
# Rate                         int64
# Tax                        float64
# total_amt                  float64
# Store_type                  object
# prod_cat                    object
# prod_subcat                 object
# dtype: object

# %%
Customer_Final['DOB'] = pd.to_datetime(Customer_Final['DOB'])

# %%
from datetime import datetime 
now = datetime.now()

# %%
now
# Out:
# datetime.datetime(2019, 6, 17, 17, 32, 2, 891136)

# %%
Customer_Final['age'] = (now - Customer_Final['DOB']).astype('<m8[Y]') 
Customer_Final['age']
# Out:
# 0        49.0
# 1        49.0
# 2        49.0
# 3        49.0
# 4        49.0
# 5        49.0
# 6        49.0
# 7        49.0
# 8        49.0
# 9        49.0
# 10       49.0
# 11       49.0
# 12       49.0
# 13       49.0
# 14       49.0
# 15       49.0
# 16       49.0
# 17       49.0
# 18       49.0
# 19       49.0
# 20       48.0
# 21       49.0
# 22       48.0
# 23       48.0
# 24       48.0
# 25       48.0
# 26       48.0
# 27       49.0
# 28       48.0
# 29       48.0
#          ...
# 23023    26.0
# 23024    26.0
# 23025    27.0
# 23026    27.0
# 23027    27.0
# 23028    26.0
# 23029    26.0
# 23030    26.0
# 23031    26.0
# 23032    26.0
# 23033    26.0
# 23034    26.0
# 23035    27.0
# 23036    26.0
# 23037    26.0
# 23038    26.0
# 23039    26.0
# 23040    26.0
# 23041    26.0
# 23042    26.0
# 23043    26.0
# 23044    26.0
# 23045    26.0
# 23046    27.0
# 23047    27.0
# 23048    27.0
# 23049    26.0
# 23050    26.0
# 23051    26.0
# 23052    26.0
# ...

# %%
Customer_Final['age'] = Customer_Final['age'].astype(int)

# %%
Customer_Final['age']
# Out:
# 0        49
# 1        49
# 2        49
# 3        49
# 4        49
# 5        49
# 6        49
# 7        49
# 8        49
# 9        49
# 10       49
# 11       49
# 12       49
# 13       49
# 14       49
# 15       49
# 16       49
# 17       49
# 18       49
# 19       49
# 20       48
# 21       49
# 22       48
# 23       48
# 24       48
# 25       48
# 26       48
# 27       49
# 28       48
# 29       48
#          ..
# 23023    26
# 23024    26
# 23025    27
# 23026    27
# 23027    27
# 23028    26
# 23029    26
# 23030    26
# 23031    26
# 23032    26
# 23033    26
# 23034    26
# 23035    27
# 23036    26
# 23037    26
# 23038    26
# 23039    26
# 23040    26
# 23041    26
# 23042    26
# 23043    26
# 23044    26
# 23045    26
# 23046    27
# 23047    27
# 23048    27
# 23049    26
# 23050    26
# 23051    26
# 23052    26
# Name: age, Length: 23053, dtype: int32

# %%
Customer_Final.head()
# Out:
#          DOB Gender  city_code  cust_id  transaction_id   tran_date  \
# 0 1970-02-01      M        4.0   268408     87243835584  13-01-2014
# 1 1970-01-16      M        4.0   275152     73109425404  25-03-2011
# 2 1970-01-18      F        4.0   275034     64777271023  23-05-2011
# 3 1970-01-22      F        8.0   270829     87174343938   9/12/2013
# 4 1970-01-29      F        7.0   267657     76242744953  23-05-2013
#
#    prod_subcat_code  prod_cat_code  Qty  Rate      Tax  total_amt  \
# 0                 7              5    5   187   98.175   1033.175
# 1                 7              5    2   464   97.440   1025.440
# 2                 7              5    2   197   41.370    435.370
# 3                 7              5    4  1141  479.220   5043.220
# 4                 7              5    4  1020  428.400   4508.400
#
#        Store_type prod_cat prod_subcat  age
# 0        TeleShop    Books     Fiction   49
# 1          e-Shop    Books     Fiction   49
# ...

# %%
age_cal = Customer_Final.loc[(Customer_Final.age>=25) & (Customer_Final.age<=35),].reset_index(drop=True)

# %%
age_cal
# Out:
#             DOB Gender  city_code  cust_id  transaction_id   tran_date  \
# 0    1983-12-03      F        8.0   269016     21343464583  29-11-2012
# 1    1983-08-04      F       10.0   275131     25208670684  21-07-2011
# 2    1983-08-04      F        5.0   270087     51649613761  18-11-2012
# 3    1983-10-04      M        8.0   274541     63063470656  25-05-2011
# 4    1983-12-05      M        9.0   274575       739835731    1/1/2013
# 5    1983-09-06      F        6.0   267227     38436575359    6/2/2011
# 6    1983-10-06      F        8.0   273503     79736271969  14-12-2011
# 7    1983-06-21      M        7.0   273477     26177724326    5/6/2012
# 8    1983-06-21      M        7.0   273477     48177174673  26-02-2012
# 9    1983-06-26      M        1.0   268649      2709160186  26-11-2012
# 10   1983-06-29      F        1.0   267277     90669117124   12/8/2011
# 11   1983-07-14      F        6.0   272327     89912357173  21-08-2011
# ...

# %% [markdown]
# #

# %%
Customer_Final.groupby(['prod_cat']).count()
# Out:
#                    DOB  Gender  city_code  cust_id  transaction_id  tran_date  \
# prod_cat
# Bags              1998    1998       1997     1998            1998       1998
# Books             6069    6065       6068     6069            6069       6069
# Clothing          2960    2957       2960     2960            2960       2960
# Electronics       4898    4898       4894     4898            4898       4898
# Footwear          2999    2998       2999     2999            2999       2999
# Home and kitchen  4129    4128       4127     4129            4129       4129
#
#                   prod_subcat_code  prod_cat_code   Qty  Rate   Tax  \
# prod_cat
# Bags                          1998           1998  1998  1998  1998
# Books                         6069           6069  6069  6069  6069
# Clothing                      2960           2960  2960  2960  2960
# Electronics                   4898           4898  4898  4898  4898
# ...

# %%
age_pro_cat_amt = Customer_Final.groupby(['age','prod_cat'])[['total_amt']].sum()
age_pro_cat_amt
# Out:
#                        total_amt
# age prod_cat
# 26  Bags               89097.255
#     Books             327096.575
#     Clothing          126297.080
#     Electronics       202515.560
#     Footwear          192317.515
#     Home and kitchen  194392.705
# 27  Bags              149245.720
#     Books             571180.025
#     Clothing          280493.200
#     Electronics       479687.130
#     Footwear          246407.265
#     Home and kitchen  371836.920
# 28  Bags              167574.355
#     Books             429955.500
#     Clothing          304556.785
#     Electronics       366879.890
#     Footwear          237682.185
#     Home and kitchen  356313.880
# 29  Bags              207143.300
#     Books             530279.555
#     Clothing          319063.225
#     Electronics       486150.275
#     Footwear          277626.830
#     Home and kitchen  349460.670
# 30  Bags              214502.600
#     Books             565672.705
#     Clothing          298545.585
# ...

# %%
pd.pivot_table(Customer_Final, index = ['age','prod_cat','total_amt'], aggfunc='mean')
# Out:
#                                 Qty    Rate      Tax  city_code   cust_id  \
# age prod_cat         total_amt
# 26  Bags             -2907.255 -3.0  -877.0  276.255        7.0  270350.0
#                      -1216.605 -3.0  -367.0  115.605       10.0  270786.0
#                      -624.325  -1.0  -565.0   59.325        3.0  272143.0
#                       334.815   3.0   101.0   31.815        4.0  269564.0
#                       361.335   3.0   109.0   34.335        2.0  267913.0
#                       408.850   2.0   185.0   38.850        7.0  269661.0
#                       479.570   2.0   217.0   45.570        4.0  272745.0
#                       624.325   1.0   565.0   59.325        3.0  272143.0
#                       709.410   2.0   321.0   67.410       10.0  267952.0
#                       740.350   2.0   335.0   70.350        6.0  274339.0
#                       928.200   5.0   168.0   88.200       10.0  271195.0
# ...

# %%
stacked_age_pro_cat_amt=age_pro_cat_amt.stack()
stacked_age_pro_cat_amt
# Out:
# age  prod_cat
# 26   Bags              total_amt     89097.255
#      Books             total_amt    327096.575
#      Clothing          total_amt    126297.080
#      Electronics       total_amt    202515.560
#      Footwear          total_amt    192317.515
#      Home and kitchen  total_amt    194392.705
# 27   Bags              total_amt    149245.720
#      Books             total_amt    571180.025
#      Clothing          total_amt    280493.200
#      Electronics       total_amt    479687.130
#      Footwear          total_amt    246407.265
#      Home and kitchen  total_amt    371836.920
# 28   Bags              total_amt    167574.355
#      Books             total_amt    429955.500
#      Clothing          total_amt    304556.785
#      Electronics       total_amt    366879.890
#      Footwear          total_amt    237682.185
#      Home and kitchen  total_amt    356313.880
# 29   Bags              total_amt    207143.300
#      Books             total_amt    530279.555
# ...

# %%
Customer_Final.groupby(['prod_cat'])[['total_amt']].count()

# %%
Calcuation = Customer_Final.loc[(Customer_Final.prod_cat == 'Electronics') & (Customer_Final.Gender == 'M'),]
Calcuation

# %%
age_cal = Customer_Final.loc[(Customer_Final.age>=25) & (Customer_Final.age<=35)[(Customer_Final.prod_cat == 'Electronics',)],].reset_index(drop=True)
# Out:
#   File "<ipython-input-322-0a204a4506f4>", line 1
#     age_cal = Customer_Final.loc[(Customer_Final.age>=25) & (Customer_Final.age<=35){[(Customer_Final.prod_cat == 'Electronics','Books')]},].reset_index(drop=True)
#                                                                                     ^
# SyntaxError: invalid syntax

# %%
age_cal.count()
# Out:
# DOB                 0
# Gender              0
# city_code           0
# cust_id             0
# transaction_id      0
# tran_date           0
# prod_subcat_code    0
# prod_cat_code       0
# Qty                 0
# Rate                0
# Tax                 0
# total_amt           0
# Store_type          0
# prod_cat            0
# prod_subcat         0
# age                 0
# dtype: int64

# %%
age_cal = Customer_Final.loc[(Customer_Final.age>=25) & (Customer_Final.age<=35)[[Customer_Final[Customer_Final[Customer_Final['prod_cat'].isin(['Electronics', 'Books'])]]],]
# Out:
#   File "<ipython-input-333-57672f3a3fed>", line 2
#
#     ^
# SyntaxError: unexpected EOF while parsing

# %%
cond2 = Customer_Final[Customer_Final['prod_cat'].isin(['Electronics', 'Books'])]
               
               #df[df['A'].isin([3, 6])]
        cond2.sum()
# Out:
#   File "<ipython-input-356-acfca49bab80>", line 4
#     cond2.sum()
#     ^
# IndentationError: unexpected indent

# %%
cond1 = Customer_Final.loc[(Customer_Final.age>=25) & (Customer_Final.age<=35)]

# %%
condition =  Customer_Final[Customer_Final['prod_cat'].isin(['Electronics', 'Books'])].loc[(Customer_Final.age>=25) & (Customer_Final.age<=35)]

# %%
answer11a = condition[['total_amt']].sum()

# %%
answer11a
# Out:
# total_amt    9758210.8
# dtype: float64

# %%
Customer_Final['total_amt'].sum()
# Out:
# 48579771.37

# %%
v = round(29.9)

# %%
v
# Out:
# 30
