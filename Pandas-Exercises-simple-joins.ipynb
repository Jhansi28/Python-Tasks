# %% [markdown]
# # MPG Cars

# %% [markdown]
# ### Introduction:
#
# The following exercise utilizes data from [UC Irvine Machine Learning Repository](https://archive.ics.uci.edu/ml/datasets/Auto+MPG)
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Step 2. Import the  datasets [cars1.csv](https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/Merge/Auto_MPG/cars1.csv) and [cars2.csv](https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/Merge/Auto_MPG/cars2.csv) from the folder

# %%
cars1.dtypes
# Out:
# mpg             float64
# cylinders         int64
# displacement      int64
# horsepower       object
# weight            int64
# acceleration    float64
# model             int64
# origin            int64
# car              object
# Unnamed: 9      float64
# Unnamed: 10     float64
# Unnamed: 11     float64
# Unnamed: 12     float64
# Unnamed: 13     float64
# dtype: object

# %% [markdown]
#    ### Step 3. Assign each to a to a variable called cars1 and cars2

# %%
cars1 = pd.read_csv("C:/Users/Latha/Desktop/Assignment/cars1.csv")

# %%
cars2 = pd.read_csv("C:/Users/Latha/Desktop/Assignment/cars2.csv")

# %%
cars2.head(2)
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 0  33.0          4            91         53    1795          17.4     76
# 1  20.0          6           225        100    3651          17.7     76
#
#    origin             car
# 0       3     honda civic
# 1       1  dodge aspen se

# %%
cars1.shape
# Out:
# (198, 14)

# %%
cars2.shape
# Out:
# (200, 9)

# %%
drop_data=['']

# %% [markdown]
# ### Step 4. It seems our first dataset has some unnamed blank columns, fix cars1

# %%
cars1.isnull()
# Out:
#        mpg  cylinders  displacement  horsepower  weight  acceleration  model  \
# 0    False      False         False       False   False         False  False
# 1    False      False         False       False   False         False  False
# 2    False      False         False       False   False         False  False
# 3    False      False         False       False   False         False  False
# 4    False      False         False       False   False         False  False
# 5    False      False         False       False   False         False  False
# 6    False      False         False       False   False         False  False
# 7    False      False         False       False   False         False  False
# 8    False      False         False       False   False         False  False
# 9    False      False         False       False   False         False  False
# 10   False      False         False       False   False         False  False
# ...

# %%
cars1.dropna(axis = 1, inplace = True)

# %%
cars1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 198 entries, 0 to 197
# Data columns (total 9 columns):
# mpg             198 non-null float64
# cylinders       198 non-null int64
# displacement    198 non-null int64
# horsepower      198 non-null object
# weight          198 non-null int64
# acceleration    198 non-null float64
# model           198 non-null int64
# origin          198 non-null int64
# car             198 non-null object
# dtypes: float64(2), int64(5), object(2)
# memory usage: 14.0+ KB

# %%
cars1.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 0  18.0          8           307        130    3504          12.0     70
# 1  15.0          8           350        165    3693          11.5     70
# 2  18.0          8           318        150    3436          11.0     70
# 3  16.0          8           304        150    3433          12.0     70
# 4  17.0          8           302        140    3449          10.5     70
#
#    origin                        car
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
cars1.isnull().sum()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      0
# weight          0
# acceleration    0
# model           0
# origin          0
# car             0
# dtype: int64

# %% [markdown]
# ### Step 5. What is the number of observations in each dataset?

# %%
cars1.shape
# Out:
# (198, 9)

# %%
cars2.shape
# Out:
# (200, 9)

# %% [markdown]
# # Step 6. Join cars1 and cars2 into a single DataFrame called cars

# %%
frame = [cars1, cars2]

# %%
cars = pd.concat(frame)

# %%
cars.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 0  18.0          8           307        130    3504          12.0     70
# 1  15.0          8           350        165    3693          11.5     70
# 2  18.0          8           318        150    3436          11.0     70
# 3  16.0          8           304        150    3433          12.0     70
# 4  17.0          8           302        140    3449          10.5     70
#
#    origin                        car
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
cars.shape
# Out:
# (398, 10)

# %%
cars.columns.values
# Out:
# array(['mpg', 'cylinders', 'displacement', 'horsepower', 'weight',
#        'acceleration', 'model', 'origin', 'car', 'owners'], dtype=object)

# %%
cars['origin'].count()
# Out:
# 398

# %% [markdown]
# # Step 7. There is a column missing, called owners. Create a random number Series from 15,000 to 73,000.

# %%
cars['owners'] = np.random.randint(15000, 73000, size = len(cars))

# %%
cars.shape
# Out:
# (398, 10)

# %% [markdown]
# ### Step 8. Add the column owners to cars

# %%
cars['owners'] = np.random.randint(15000, 73000, size = len(cars))

# %%
cars.shape
# Out:
# (398, 10)

# %%
cars = cars.reset_index(drop = True)

# %%
cars.tail()
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 195  27.0          4           140         86    2790          15.6     82
# 196  44.0          4            97         52    2130          24.6     82
# 197  32.0          4           135         84    2295          11.6     82
# 198  28.0          4           120         79    2625          18.6     82
# 199  31.0          4           119         82    2720          19.4     82
#
#      origin              car  owners
# 195       1  ford mustang gl   70509
# 196       2        vw pickup   31601
# 197       1    dodge rampage   33742
# 198       1      ford ranger   54587
# 199       1       chevy s-10   52315

# %%
cars.describe()
# Out:
#               mpg   cylinders  displacement       weight  acceleration  \
# count  398.000000  398.000000    398.000000   398.000000    398.000000
# mean    23.514573    5.454774    193.427136  2970.424623     15.568090
# std      7.815984    1.701004    104.268683   846.841774      2.757689
# min      9.000000    3.000000     68.000000  1613.000000      8.000000
# 25%     17.500000    4.000000    104.250000  2223.750000     13.825000
# 50%     23.000000    4.000000    148.500000  2803.500000     15.500000
# 75%     29.000000    8.000000    262.000000  3608.000000     17.175000
# max     46.600000    8.000000    455.000000  5140.000000     24.800000
#
#             model      origin        owners
# count  398.000000  398.000000    398.000000
# mean    76.010050    1.572864  43689.497487
# std      3.697627    0.802055  16688.117411
# min     70.000000    1.000000  15068.000000
# 25%     73.000000    1.000000  28935.250000
# 50%     76.000000    1.000000  44237.500000
# ...

# %%
cars.loc[199,:]
# Out:
# mpg                     31
# cylinders                4
# displacement           119
# horsepower              82
# weight                2720
# acceleration          19.4
# model                   82
# origin                   1
# car             chevy s-10
# owners               61969
# Name: 199, dtype: object
