# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
provider_charge_inpatient = pd.read_csv("C:/Users/Latha/Desktop/End to End Case study/Medicare_Provider_Charge_Inpatient_DRG100_FY2011.csv")

# %%
provider_charge_inpatient.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 163065 entries, 0 to 163064
# Data columns (total 12 columns):
# DRG Definition                                163065 non-null object
# Provider Id                                   163065 non-null int64
# Provider Name                                 163065 non-null object
# Provider Street Address                       163065 non-null object
# Provider City                                 163065 non-null object
# Provider State                                163065 non-null object
# Provider Zip Code                             163065 non-null int64
# Hospital Referral Region (HRR) Description    163065 non-null object
# Total Discharges                              163065 non-null int64
# Average Covered Charges                       163065 non-null float64
# Average Total Payments                        163065 non-null float64
# Average Medicare Payments                     163065 non-null float64
# ...

# %%
provider_charge_inpatient.head(2)
# Out:
#                              DRG Definition  Provider Id  \
# 0  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC        10001
# 1  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC        10005
#
#                       Provider Name     Provider Street Address Provider City  \
# 0  SOUTHEAST ALABAMA MEDICAL CENTER      1108 ROSS CLARK CIRCLE        DOTHAN
# 1     MARSHALL MEDICAL CENTER SOUTH  2505 U S HIGHWAY 431 NORTH          BOAZ
#
#   Provider State  Provider Zip Code  \
# 0             AL              36301
# 1             AL              35957
#
#   Hospital Referral Region (HRR) Description  Total Discharges  \
# 0                                AL - Dothan                91
# 1                            AL - Birmingham                14
#
#    Average Covered Charges  Average Total Payments  Average Medicare Payments
# 0              32963.07692             5777.241758                4763.736264
# 1              15131.85714             5787.571429                4976.714286

# %%
provider_charge_inpatient.shape
# Out:
# (163065, 12)

# %%
provider_charge_inpatient.boxplot(by ='Provider Name', column =['Average Total Payments'], grid = False)

# %%
provider_charge_inpatient.groupby(['DRG Definition'])[['Average Total Payments']].sum()
# Out:
#                                                     Average Total Payments
# DRG Definition
# 039 - EXTRACRANIAL PROCEDURES W/O CC/MCC                      7.510420e+06
# 057 - DEGENERATIVE NERVOUS SYSTEM DISORDERS W/O...            8.054243e+06
# 064 - INTRACRANIAL HEMORRHAGE OR CEREBRAL INFAR...            2.200469e+07
# 065 - INTRACRANIAL HEMORRHAGE OR CEREBRAL INFAR...            1.797655e+07
# 066 - INTRACRANIAL HEMORRHAGE OR CEREBRAL INFAR...            1.031946e+07
# 069 - TRANSIENT ISCHEMIA                                      9.944688e+06
# 074 - CRANIAL & PERIPHERAL NERVE DISORDERS W/O MCC            6.252674e+06
# 101 - SEIZURES W/O MCC                                        8.750932e+06
# 149 - DYSEQUILIBRIUM                                          4.534039e+06
# 176 - PULMONARY EMBOLISM W/O MCC                              1.016282e+07
# 177 - RESPIRATORY INFECTIONS & INFLAMMATIONS W MCC            2.619286e+07
# ...

# %%
# import matplotlib
import matplotlib.pyplot as plt
# import seaborn
import seaborn as sns
# %matplotlib inline

# %%
data_url = 'http://bit.ly/2cLzoxH'
# read data from url as pandas dataframe
gapminder = pd.read_csv(data_url)
print(gapminder.head(3))
# Out:
#        country  year         pop continent  lifeExp   gdpPercap
# 0  Afghanistan  1952   8425333.0      Asia   28.801  779.445314
# 1  Afghanistan  1957   9240934.0      Asia   30.332  820.853030
# 2  Afghanistan  1962  10267083.0      Asia   31.997  853.100710

# %%
gapminder.groupby(['continent'])[['continent']].count()
# Out:
#            continent
# continent
# Africa           624
# Americas         300
# Asia             396
# Europe           360
# Oceania           24

# %%
provider_outpatient_charge = pd.read_csv("C:/Users/Latha/Desktop/End to End Case study/Medicare_Provider_Charge_Outpatient_APC30_CY2011_v2 (1).csv")

# %%
provider_outpatient_charge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43372 entries, 0 to 43371
# Data columns (total 12 columns):
# APC                                           43372 non-null object
# Provider Id                                   43372 non-null int64
# Provider Name                                 43372 non-null object
# Provider Street Address                       43372 non-null object
# Provider City                                 43372 non-null object
# Provider State                                43372 non-null object
# Provider Zip Code                             43372 non-null int64
# Hospital Referral Region (HRR) Description    43372 non-null object
# Outpatient Services                           43372 non-null int64
# Average  Estimated Submitted Charges          43372 non-null float64
# Average Total Payments                        43372 non-null float64
# New_APC                                       43372 non-null int64
# dtypes: float64(2), int64(4), object(6)
# ...

# %%
provider_outpatient_charge.head(2)
# Out:
#                                         APC  Provider Id  \
# 0  0012 - Level I Debridement & Destruction        10029
# 1  0012 - Level I Debridement & Destruction        20024
#
#                          Provider Name Provider Street Address Provider City  \
# 0  EAST ALABAMA MEDICAL CENTER AND SNF  2000 PEPPERELL PARKWAY       OPELIKA
# 1   CENTRAL PENINSULA GENERAL HOSPITAL      250 HOSPITAL PLACE      SOLDOTNA
#
#   Provider State  Provider Zip Code  \
# 0             AL              36801
# 1             AK              99669
#
#   Hospital Referral Region (HRR) Description  Outpatient Services  \
# 0                            AL - Birmingham                   23
# 1                             AK - Anchorage                  994
#
#    Average  Estimated Submitted Charges  Average Total Payments  New_APC
# 0                             78.086957               21.910435       12
# 1                            149.589749               36.623853       12

# %%
d = provider_outpatient_charge.groupby(by = ['APC'])[['APC']].count()
d
# Out:
#                                                      APC
# APC
# 0012 - Level I Debridement & Destruction             291
# 0013 - Level II Debridement & Destruction           1479
# 0015 - Level III Debridement & Destruction          1534
# 0019 - Level I Excision/ Biopsy                      445
# 0020 - Level II Excision/ Biopsy                    1060
# 0073 - Level III Endoscopy Upper Airway               95
# 0074 - Level IV Endoscopy Upper Airway               411
# 0078 - Level III Pulmonary Treatment                2304
# 0096 - Level II Noninvasive Physiologic Studies     1889
# 0203 - Level IV Nerve Injections                     131
# 0204 - Level I Nerve Injections                     1657
# 0206 - Level II Nerve Injections                     769
# 0207 - Level III Nerve Injections                   2002
# 0209 - Level II Extended EEG, Sleep, and Cardio...  1967
# 0265 - Level I Diagnostic and Screening Ultrasound  2739
# ...

# %%
total = provider_outpatient_charge.groupby(['APC']).nunique().count()
total
# Out:
# APC                                           30
# Provider_Id                                   30
# Provider_Name                                 30
# Provider_Street_Address                       30
# Provider_City                                 30
# Provider_State                                30
# Provider_Zip_Code                             30
# Hospital_Referral_Region_(HRR)_Description    30
# Outpatient_Services                           30
# Average__Estimated_Submitted_Charges          30
# Average_Total_Payments                        30
# dtype: int64

# %%
provider_outpatient_charge.describe()
# Out:
#          Provider_Id  Provider_Zip_Code  Outpatient_Services  \
# count   43372.000000       43372.000000         43372.000000
# mean   265410.921747       49041.022434           587.980955
# std    152729.927698       27497.899751          3280.397168
# min     10001.000000        1040.000000            11.000000
# 25%    140043.000000       28645.000000            42.000000
# 50%    260091.000000       46342.000000           128.000000
# 75%    390101.000000       73101.000000           347.000000
# max    670061.000000       99801.000000        219042.000000
#
#        Average__Estimated_Submitted_Charges  Average_Total_Payments
# count                          43372.000000            43372.000000
# mean                            1473.994047              265.425586
# std                             1837.530791              261.260146
# min                               12.643750                7.305000
# 25%                              284.610498               74.627714
# ...

# %%
provider_outpatient_charge.shape
# Out:
# (43372, 11)

# %%
# data.columns = [col.replace('.', '_') for col in data.columns]
provider_outpatient_charge.columns = [col.replace(' ' , '_') for col in provider_outpatient_charge.columns]

# %%
boxplot = provider_outpatient_charge.boxplot(by = 'New_APC',figsize = (15,7), column=['Average  Estimated Submitted Charges'])

# %%
provider_outpatient_charge.loc[(provider_outpatient_charge['New_APC']==74)].sort_values(by = ['Average  Estimated Submitted Charges'], ascending = False)
# Out:
#                                          APC  Provider Id  \
# 4983  0074 - Level IV Endoscopy Upper Airway       100223
# 4939  0074 - Level IV Endoscopy Upper Airway        50764
# 4981  0074 - Level IV Endoscopy Upper Airway       100179
# 4925  0074 - Level IV Endoscopy Upper Airway        50133
# 4937  0074 - Level IV Endoscopy Upper Airway        50625
# 4966  0074 - Level IV Endoscopy Upper Airway       100071
# 4934  0074 - Level IV Endoscopy Upper Airway        50454
# 5269  0074 - Level IV Endoscopy Upper Airway       450299
# 5074  0074 - Level IV Endoscopy Upper Airway       220110
# 4957  0074 - Level IV Endoscopy Upper Airway       100008
# 4982  0074 - Level IV Endoscopy Upper Airway       100204
# 4958  0074 - Level IV Endoscopy Upper Airway       100009
# 5119  0074 - Level IV Endoscopy Upper Airway       260065
# 5294  0074 - Level IV Endoscopy Upper Airway       490059
# 5018  0074 - Level IV Endoscopy Upper Airway       140281
# ...

# %%
provider_outpatient_charge.loc[(provider_outpatient_charge['New_APC']==19)].sort_values(by = ['Average  Estimated Submitted Charges'], ascending = False)
# Out:
#                                   APC  Provider Id  \
# 3336  0019 - Level I Excision/ Biopsy        50739
# 3335  0019 - Level I Excision/ Biopsy        50735
# 3521  0019 - Level I Excision/ Biopsy       250122
# 3681  0019 - Level I Excision/ Biopsy       420091
# 3717  0019 - Level I Excision/ Biopsy       490069
# 3677  0019 - Level I Excision/ Biopsy       420010
# 3311  0019 - Level I Excision/ Biopsy        10131
# 3678  0019 - Level I Excision/ Biopsy       420023
# 3306  0019 - Level I Excision/ Biopsy        10055
# 3360  0019 - Level I Excision/ Biopsy       100243
# 3305  0019 - Level I Excision/ Biopsy        10046
# 3426  0019 - Level I Excision/ Biopsy       180036
# 3324  0019 - Level I Excision/ Biopsy        50093
# 3712  0019 - Level I Excision/ Biopsy       490017
# 3346  0019 - Level I Excision/ Biopsy       100006
# 3518  0019 - Level I Excision/ Biopsy       250094
# 3322  0019 - Level I Excision/ Biopsy        50002
# ...

# %%
provider_outpatient_charge.loc[(provider_outpatient_charge['New_APC']==20)].sort_values(by = ['Average  Estimated Submitted Charges'], ascending = False)
# Out:
#                                    APC  Provider Id  \
# 3874  0020 - Level II Excision/ Biopsy        50678
# 3754  0020 - Level II Excision/ Biopsy        10024
# 4597  0020 - Level II Excision/ Biopsy       390162
# 4365  0020 - Level II Excision/ Biopsy       310118
# 4046  0020 - Level II Excision/ Biopsy       140174
# 4756  0020 - Level II Excision/ Biopsy       490112
# 3876  0020 - Level II Excision/ Biopsy        50696
# 3997  0020 - Level II Excision/ Biopsy       110115
# 4719  0020 - Level II Excision/ Biopsy       450711
# 3872  0020 - Level II Excision/ Biopsy        50625
# 4718  0020 - Level II Excision/ Biopsy       450678
# 4758  0020 - Level II Excision/ Biopsy       490118
# 3808  0020 - Level II Excision/ Biopsy        40078
# 3968  0020 - Level II Excision/ Biopsy       100249
# 3878  0020 - Level II Excision/ Biopsy        50742
# 3928  0020 - Level II Excision/ Biopsy       100049
# 4689  0020 - Level II Excision/ Biopsy       450119
# ...

# %% [raw]
# PART 1A: HIGHEST COST VARIATION
#     Claimed Charges for the Three Procedures That Have the Highest Coefficient of Variation ARE
#             PROCEDURE                                         COST
#    ----------------------------------------------------------------------------------------------
#     1. 0074 - Level IV Endoscopy Upper Airway                32105.63636
#
#     2. 0019 - Level I Excision/ Biopsy                       26466.645
#
#     3. 0020 - Level II Excision/ Biopsy                      19018.40882
#
#     -----------------------------------------------------------------------------------------

# %%
provider_outpatient_charge.groupby(by = ['Provider Name','New_APC'])[['Average  Estimated Submitted Charges']].sum()
# Out:
#                                       Average  Estimated Submitted Charges
# Provider Name                New_APC
# ABBEVILLE GENERAL HOSPITAL   78                                 474.600000
#                              207                               1678.255618
#                              265                                269.422400
#                              267                                682.084968
#                              269                               1253.660000
#                              368                                219.118421
#                              604                                127.870238
# ABBOTT NORTHWESTERN HOSPITAL 13                                 381.670000
#                              15                                 238.657418
#                              20                                6081.384091
#                              73                                1319.513333
# ...

# %%
b = provider_outpatient_charge.groupby(by = ['Provider Name'])

# %%
resut = b[['APC','Average  Estimated Submitted Charges']].sum()

# %%
resut.sort_values(by = ['Average  Estimated Submitted Charges'], ascending = False)
# Out:
#                                                Average  Estimated Submitted Charges
# Provider Name
# GOOD SAMARITAN HOSPITAL                                               180624.500377
# ST JOSEPH HOSPITAL                                                    164340.786103
# ST JOSEPH MEDICAL CENTER                                              145452.571951
# DOCTORS HOSPITAL                                                      132935.875166
# ST MARY MEDICAL CENTER                                                121592.804476
# ST FRANCIS HOSPITAL                                                   116433.874949
# BAPTIST MEDICAL CENTER                                                112370.954032
# MEMORIAL HOSPITAL                                                     102855.756911
# NORTHWEST MEDICAL CENTER                                              102593.332645
# CEDARS-SINAI MEDICAL CENTER                                            99045.006821
# ...

# %%
resut1 = b[['Average  Estimated Submitted Charges', 'APC']].sum()
resut1
# Out:
#                                                Average  Estimated Submitted Charges
# Provider Name
# ABBEVILLE GENERAL HOSPITAL                                              4705.011645
# ABBOTT NORTHWESTERN HOSPITAL                                           41719.927838
# ABILENE REGIONAL MEDICAL CENTER                                        26020.974755
# ABINGTON MEMORIAL HOSPITAL                                             45404.932674
# ACMH HOSPITAL                                                          14984.899082
# ADENA REGIONAL MEDICAL CENTER                                          18725.016754
# ADIRONDACK MEDICAL CENTER                                              12315.976390
# ADVENTIST BOLINGBROOK HOSPITAL                                         25061.944274
# ADVENTIST GLENOAKS                                                     19253.255113
# ADVENTIST LA GRANGE MEMORIAL HOSPITAL                                  31002.596850
# ...

# %%
resut1.sort_values(by = ['New_APC', 'Average  Estimated Submitted Charges'], ascending = False)
# Out:
#                                             New_APC  \
# Provider Name
# GOOD SAMARITAN HOSPITAL                         116
# ST JOSEPH MEDICAL CENTER                        111
# ST JOSEPH HOSPITAL                              106
# MERCY HOSPITAL                                   87
# MERCY MEDICAL CENTER                             82
# MEMORIAL HOSPITAL                                78
# ST FRANCIS MEDICAL CENTER                        75
# ST MARY'S MEDICAL CENTER                         72
# ST MARYS HOSPITAL                                69
# ST FRANCIS HOSPITAL                              67
# ST LUKES HOSPITAL                                63
# DOCTORS HOSPITAL                                 61
# ST MARY MEDICAL CENTER                           61
# GRADY MEMORIAL HOSPITAL                          55
# NORTHWEST MEDICAL CENTER                         50
# SACRED HEART HOSPITAL                            50
# COMMUNITY HOSPITAL                               46
# ...

# %% [raw]
# PART 1B: HIGHEST COST CLAIMS BY PROVIDER
#
# The three providers who claim the highest charges for the most number of procedures are:
# -------------------------------------------------------------------------------------------------
# Provider                             No. Of Proceders                  Charges
# -------------------------------------------------------------------------------------------------
# 1. GOOD SAMARITAN HOSPITAL           116                                180624.500377
#
# 2. ST JOSEPH HOSPITAL                111                                164340.786103
#
# 3. ST JOSEPH MEDICAL CENTER          106                                145452.571951
#
# -------------------------------------------------------------------------------------------------

# %% [raw]
# PART1C: HIGHEST COST CLAIMS BY REGION
# The three regions in which patients are charged the highest amount for the most medical procedures are
#
# REGION                        APC                                       PROCEDURE COST
# --------------------------------------------------------------------------------------------
# 1. CA - Los Angeles           0377 - Level II Cardiac Imaging            321490.361825
#
# 2. TX - Houston               0377 - Level II Cardiac Imaging	         259296.941125
#
# 3. GA - Atlanta               0377 - Level II Cardiac Imaging	         243137.082557
#
# -------------------------------------------------------------------------------------------------

# %%
C = provider_outpatient_charge.groupby(by = ['Hospital Referral Region (HRR) Description'])

# %%
resut4 = C[['APC','Average  Estimated Submitted Charges']].count()
resut4
# Out:
#                                             APC  \
# Hospital Referral Region (HRR) Description
# AK - Anchorage                               84
# AL - Birmingham                             444
# AL - Dothan                                 105
# AL - Huntsville                             104
# AL - Mobile                                 156
# AL - Montgomery                              88
# AL - Tuscaloosa                              49
# AR - Fort Smith                              76
# AR - Jonesboro                               60
# AR - Little Rock                            344
# AR - Springdale                              80
# AR - Texarkana                               64
# AZ - Mesa                                    94
# AZ - Phoenix                                370
# AZ - Sun City                                30
# AZ - Tucson                                 143
# CA - Alameda County                         101
# CA - Bakersfield                             77
# ...

# %%
resut4.sort_values(by = ['APC', 'Average  Estimated Submitted Charges'], ascending = False)
# Out:
#                                             APC  \
# Hospital Referral Region (HRR) Description
# MA - Boston                                 799
# CA - Los Angeles                            725
# GA - Atlanta                                716
# TX - Houston                                709
# TX - Dallas                                 633
# PA - Pittsburgh                             626
# MO - St. Louis                              604
# IN - Indianapolis                           580
# PA - Philadelphia                           579
# TN - Nashville                              530
# MO - Kansas City                            512
# MN - Minneapolis                            472
# WI - Milwaukee                              469
# AL - Birmingham                             444
# OH - Columbus                               439
# OH - Cleveland                              432
# FL - Orlando                                410
# NY - East Long Island                       403
# ...

# %%
C = provider_outpatient_charge.groupby(by = ['Hospital Referral Region (HRR) Description', 'APC'])

# %%
resut2 = C[['APC','Average  Estimated Submitted Charges']].sum()

# %%
resut2.sort_values(by = ['Average  Estimated Submitted Charges'], ascending = False)
# Out:
#                                                                                                Average  Estimated Submitted Charges
# Hospital Referral Region (HRR) Description APC
# CA - Los Angeles                           0377 - Level II Cardiac Imaging                                            321490.361825
# TX - Houston                               0377 - Level II Cardiac Imaging                                            259296.941125
# GA - Atlanta                               0377 - Level II Cardiac Imaging                                            243137.082557
# PA - Philadelphia                          0377 - Level II Cardiac Imaging                                            239207.168757
# CA - Los Angeles                           0336 - Magnetic Resonance Imaging and Magnetic ...                         205840.043350
#                                            0269 - Level II Echocardiogram Without Contrast                            194849.205083
# ...

# %%
C1 = provider_outpatient_charge.groupby(by = ['Hospital Referral Region (HRR) Description'])

# %%
resut5 = C[['Average  Estimated Submitted Charges']].sum()

# %%
resut5.sort_values(by = ['Average  Estimated Submitted Charges'], ascending = False)
# Out:
#                                                                                                Average  Estimated Submitted Charges
# Hospital Referral Region (HRR) Description APC
# CA - Los Angeles                           0377 - Level II Cardiac Imaging                                            321490.361825
# TX - Houston                               0377 - Level II Cardiac Imaging                                            259296.941125
# GA - Atlanta                               0377 - Level II Cardiac Imaging                                            243137.082557
# PA - Philadelphia                          0377 - Level II Cardiac Imaging                                            239207.168757
# CA - Los Angeles                           0336 - Magnetic Resonance Imaging and Magnetic ...                         205840.043350
#                                            0269 - Level II Echocardiogram Without Contrast                            194849.205083
# ...

# %%
df= provider_outpatient_charge.groupby(by=['Hospital Referral Region (HRR) Description','New_APC'])[['Average  Estimated Submitted Charges']].mean().add_prefix('MeanOf_')

# %%
df
# Out:
#                                                     MeanOf_Average  Estimated Submitted Charges
# Hospital Referral Region (HRR) Description New_APC
# AK - Anchorage                             12                                        149.589749
#                                            13                                        235.006808
#                                            15                                        303.065921
#                                            73                                        383.386087
#                                            78                                        778.608260
#                                            96                                        647.172826
#                                            204                                       739.558303
#                                            207                                      2521.421263
# ...

# %%
df.plot(kind='pie',subplots=True,legend=False)
plt.ylabel("")
plt.show()

# %%
boxplot.set_xlabel("New_APC", 
                fontsize=20)
boxplot.tick_params(labelsize=10)

# %%
bplot = sns.boxplot(y='Average  Estimated Submitted Charges', x='New_APC', 
                 data=provider_outpatient_charge, 
                 width=0.8)

# %%
Avg = provider_outpatient_charge['Average__Estimated_Submitted_Charges']

# %%
provider_outpatient_charge['Average__Estimated_Submitted_Charges'].describe()
# Out:
# count    43372.000000
# mean      1473.994047
# std       1837.530791
# min         12.643750
# 25%        284.610498
# 50%        709.995188
# 75%       2102.121346
# max      32105.636360
# Name: Average__Estimated_Submitted_Charges, dtype: float64

# %%
import matplotlib as mp
from matplotlib import pyplot as plt   # pyplot contains graph related functions
# %matplotlib inline 


import matplotlib.pyplot as plt 
plt.boxplot(Avg)
plt.show()

# %%
ax = plt.subplots()

# %%
data = provider_outpatient_charge['Average__Estimated_Submitted_Charges'].value_counts()

# %%
# Get X and Y dataa

points = data.index
frequency = data.values

# %%
ax.bar( data.values)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-80-74b2b7d39d08> in <module>
# ----> 1 ax.bar( data.values)
#
# AttributeError: 'tuple' object has no attribute 'bar'

# %%
import matplotlib.pyplot as plt
Avg.plot(kind = "hist",bins=5,edgecolor = "black",color="red",figsize = (5,2))

# %%
provider_outpatient_charge.columns
# Out:
# Index(['APC', 'Provider_Id', 'Provider_Name', 'Provider_Street_Address',
#        'Provider_City', 'Provider_State', 'Provider_Zip_Code',
#        'Hospital_Referral_Region_(HRR)_Description', 'Outpatient_Services',
#        'Average__Estimated_Submitted_Charges', 'Average_Total_Payments'],
#       dtype='object')

# %%
import seaborn as sns
sns.distplot(provider_outpatient_charge.Average__Estimated_Submitted_Charges)

# %%
d.sort_values('Average  Estimated Submitted Charges', ascending = False)
# grouped.sort_values('mygroups', ascending=False)
# Out:
#                                                                    Average  Estimated Submitted Charges
# APC                                                Provider State
# 0377 - Level II Cardiac Imaging                    CA                                      1.217686e+06
#                                                    TX                                      9.824120e+05
#                                                    FL                                      8.301017e+05
# 0336 - Magnetic Resonance Imaging and Magnetic ... CA                                      7.739253e+05
#                                                    TX                                      7.525511e+05
# 0269 - Level II Echocardiogram Without Contrast    CA                                      6.883156e+05
# 0209 - Level II Extended EEG, Sleep, and Cardio... TX                                      6.481271e+05
# ...

# %%
provider_outpatient_charge.shape
# Out:
# (43372, 11)

# %%
medicare_charge_outpatient_summary =  pd.read_csv("C:/Users/Latha/Desktop/End to End Case study/Medicare_Charge_Outpatient_APC30_Summary_by_APC_CY2011.csv")

# %%
medicare_charge_outpatient_summary.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 4 columns):
# APC                                    30 non-null object
# Outpatient Services                    30 non-null int64
# Average Estimated Submitted Charges    30 non-null float64
# Average Total Payments                 30 non-null float64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 1.0+ KB

# %%
medicare_charge_outpatient_summary.head(2)
# Out:
#                                          APC  Outpatient Services  \
# 0   0012 - Level I Debridement & Destruction               275987
# 1  0013 - Level II Debridement & Destruction               434706
#
#    Average Estimated Submitted Charges  Average Total Payments
# 0                            74.202956               16.147079
# 1                           196.170070               56.133853

# %%
medicare_charge_outpatient_summary.describe()
# Out:
#        Outpatient Services  Average Estimated Submitted Charges  \
# count         3.000000e+01                            30.000000
# mean          8.523690e+05                          1433.838234
# std           1.650458e+06                          1617.847553
# min           6.748000e+03                            74.202956
# 25%           5.163925e+04                           280.441346
# 50%           3.082525e+05                           741.231255
# 75%           6.602912e+05                          2212.662090
# max           8.128902e+06                          6840.643287
#
#        Average Total Payments
# count               30.000000
# mean               295.262271
# std                323.549902
# min                 16.147079
# 25%                 81.430716
# 50%                164.703698
# 75%                385.374434
# max               1471.799719

# %%
medicare_charge_outpatient_summary.shape
# Out:
# (30, 4)

# %%
a = medicare_charge_outpatient_summary.groupby(['APC'])[['Average Estimated Submitted Charges']].sum().reset_index()

# %%
a.sort_values('Average Estimated Submitted Charges', ascending = False)
# grouped.sort_values('mygroups', ascending=False)
# Out:
#                                                   APC  \
# 6              0074 - Level IV Endoscopy Upper Airway
# 21                    0377 - Level II Cardiac Imaging
# 9                    0203 - Level IV Nerve Injections
# 13  0209 - Level II Extended EEG, Sleep, and Cardi...
# 4                    0020 - Level II Excision/ Biopsy
# 17   0270 - Level III Echocardiogram Without Contrast
# 18  0336 - Magnetic Resonance Imaging and Magnetic...
# 12                  0207 - Level III Nerve Injections
# 3                     0019 - Level I Excision/ Biopsy
# 16    0269 - Level II Echocardiogram Without Contrast
# 11                   0206 - Level II Nerve Injections
# 15  0267 - Level III Diagnostic and Screening Ultr...
# 20                   0369 - Level III Pulmonary Tests
# 5             0073 - Level III Endoscopy Upper Airway
# 8     0096 - Level II Noninvasive Physiologic Studies
# 10                    0204 - Level I Nerve Injections
# ...

# %%
medicare_charge_inpatient_summary =  pd.read_csv("C:/Users/Latha/Desktop/End to End Case study/Medicare_Charge_Inpatient_DRG100_DRG_Summary_by_DRG_FY2011.csv")

# %%
medicare_charge_inpatient_summary.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 5 columns):
# DRG Definition               100 non-null object
# Total Discharges             100 non-null int64
# Average Covered Charges      100 non-null float64
# Average Total Payments       100 non-null float64
# Average Medicare Payments    100 non-null float64
# dtypes: float64(3), int64(1), object(1)
# memory usage: 4.0+ KB

# %%
medicare_charge_inpatient_summary.shape
# Out:
# (100, 5)

# %%
provider_outpatient_charge['Diff_after_medicare_reimburse'] =  provider_outpatient_charge['Average  Estimated Submitted Charges'] - provider_outpatient_charge['Average Total Payments']

# %%
provider_outpatient_charge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43372 entries, 0 to 43371
# Data columns (total 13 columns):
# APC                                           43372 non-null object
# Provider Id                                   43372 non-null int64
# Provider Name                                 43372 non-null object
# Provider Street Address                       43372 non-null object
# Provider City                                 43372 non-null object
# Provider State                                43372 non-null object
# Provider Zip Code                             43372 non-null int64
# Hospital Referral Region (HRR) Description    43372 non-null object
# Outpatient Services                           43372 non-null int64
# Average  Estimated Submitted Charges          43372 non-null float64
# Average Total Payments                        43372 non-null float64
# New_APC                                       43372 non-null int64
# ...

# %%
provider_outpatient_charge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43372 entries, 0 to 43371
# Data columns (total 13 columns):
# APC                                           43372 non-null object
# Provider Id                                   43372 non-null int64
# Provider Name                                 43372 non-null object
# Provider Street Address                       43372 non-null object
# Provider City                                 43372 non-null object
# Provider State                                43372 non-null object
# Provider Zip Code                             43372 non-null int64
# Hospital Referral Region (HRR) Description    43372 non-null object
# Outpatient Services                           43372 non-null int64
# Average  Estimated Submitted Charges          43372 non-null float64
# Average Total Payments                        43372 non-null float64
# New_APC                                       43372 non-null int64
# ...

# %%
e = provider_outpatient_charge.groupby(by = ['Provider Name', 'APC'])
e

# %%
res = e[['APC','Diff_after_medicare_reimburse']].sum()

# %%
res
# Out:
#                                                                                  Diff_after_medicare_reimburse
# Provider Name                APC
# ABBEVILLE GENERAL HOSPITAL   0078 - Level III Pulmonary Treatment                                   387.400000
#                              0207 - Level III Nerve Injections                                     1225.476784
#                              0265 - Level I Diagnostic and Screening Ultrasound                     214.382400
#                              0267 - Level III Diagnostic and Screening Ultra...                     547.864140
#                              0269 - Level II Echocardiogram Without Contrast                        900.834896
#                              0368 - Level II Pulmonary Tests                                        166.998772
#                              0604 - Level 1 Hospital Clinic Visits                                   84.215238
# ...

# %% [raw]
# PART1D: Highest Number of Procedures and Largest Differences between Claims and Reimbursements
#
# The three providers who have the highest number of procedures with the largest difference between their claimed charges to patients and
# their reimbursement from Medicare are
#
# PROVIDER                                      APC                                       PROCEDURE COST
# --------------------------------------------------------------------------------------------
# 1. FORT WALTON BEACH MEDICAL CENTER           0074 - Level IV Endoscopy
# Upper Airway                                                                         30709.156360
#
# 2. SHASTA REGIONAL MEDICAL CENTER             0074 - Level IV Endoscopy              30246.490670
#
# 3. MEMORIAL HOSPITAL JACKSONVILLE             0074 - Level IV Endoscopy	             26216.221300
#
# -------------------------------------------------------------------------------------------------

# %%
res.sort_values('Diff_after_medicare_reimburse', ascending = False)
# Out:
#                                                                                                     Diff_after_medicare_reimburse
# Provider Name                                   APC
# FORT WALTON BEACH MEDICAL CENTER                0074 - Level IV Endoscopy Upper Airway                               30709.156360
# SHASTA REGIONAL MEDICAL CENTER                  0074 - Level IV Endoscopy Upper Airway                               30246.490670
# MEMORIAL HOSPITAL JACKSONVILLE                  0074 - Level IV Endoscopy Upper Airway                               26216.221300
# CENTINELA HOSPITAL MEDICAL CENTER               0019 - Level I Excision/ Biopsy                                      26073.805000
# ST JOSEPH MEDICAL CENTER                        0377 - Level II Cardiac Imaging                                      24857.235487
# RIDEOUT MEMORIAL HOSPITAL                       0074 - Level IV Endoscopy Upper Airway                               24400.961174
# ...
