# %% [markdown]
# # Filtering and Sorting Data

# %% [markdown]
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd

# %% [markdown]
# ### Step 2. Import the dataset *chipotle.tsv*

# %%
chipo = pd.read_csv("C:/Users/Latha/Desktop/Assignment/chipotle.tsv",sep="\t")

# %% [markdown]
# ### Step 3. Assign it to a variable called chipo.

# %%
chipo.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
chipo.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN      2.39
# 1                                       [Clementine]      3.39
# 2                                            [Apple]      3.39
# 3                                                NaN      2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...     16.98

# %%
chipo[chipo["item_price"]  > 10.00]
# Out:
#       order_id  quantity           item_name  \
# 4            2         2        Chicken Bowl
# 5            3         1        Chicken Bowl
# 7            4         1       Steak Burrito
# 13           7         1        Chicken Bowl
# 23          12         1     Chicken Burrito
# 39          19         1       Barbacoa Bowl
# 42          20         1        Chicken Bowl
# 43          20         1       Steak Burrito
# 45          21         1     Chicken Burrito
# 52          24         1     Chicken Burrito
# 57          26         1      Veggie Burrito
# 58          27         1       Barbacoa Bowl
# 62          28         1         Veggie Bowl
# 68          30         1     Chicken Burrito
# 79          35         1  Chicken Soft Tacos
# 90          40         1          Steak Bowl
# 91          40         1          Steak Bowl
# 93          41         1    Carnitas Burrito
# 97          43         1       Carnitas Bowl
# 123         54         1        Chicken Bowl
# ...

# %%
chipo["item_name"].nunique()
# Out:
# 50

# %% [markdown]
# ### Step 4. How many products cost more than $10.00?
#
# Use `str` attribute to remove the $ sign and convert the column to proper numeric type data before filtering.

# %%
chipo[chipo['item_price']>10].item_name.nunique()
# Out:
# 31

# %%
chipo[chipo["item_price"]  > 10.00]
# Out:
#       order_id  quantity           item_name  \
# 4            2         2        Chicken Bowl
# 5            3         1        Chicken Bowl
# 7            4         1       Steak Burrito
# 13           7         1        Chicken Bowl
# 23          12         1     Chicken Burrito
# 39          19         1       Barbacoa Bowl
# 42          20         1        Chicken Bowl
# 43          20         1       Steak Burrito
# 45          21         1     Chicken Burrito
# 52          24         1     Chicken Burrito
# 57          26         1      Veggie Burrito
# 58          27         1       Barbacoa Bowl
# 62          28         1         Veggie Bowl
# 68          30         1     Chicken Burrito
# 79          35         1  Chicken Soft Tacos
# 90          40         1          Steak Bowl
# 91          40         1          Steak Bowl
# 93          41         1    Carnitas Burrito
# 97          43         1       Carnitas Bowl
# 123         54         1        Chicken Bowl
# ...

# %%
chipo.dtypes
# Out:
# order_id                int64
# quantity                int64
# item_name              object
# choice_description     object
# item_price            float64
# dtype: object

# %%
chipo.dtypes
# Out:
# order_id               int64
# quantity               int64
# item_name             object
# choice_description    object
# item_price            object
# dtype: object

# %%
chipo["item_price"] = chipo.item_price.str.replace('$', '')

# %%
chipo[['item_price', 'item_name']]
# Out:
#       item_price                              item_name
# 0           2.39           Chips and Fresh Tomato Salsa
# 1           3.39                                   Izze
# 2           3.39                       Nantucket Nectar
# 3           2.39  Chips and Tomatillo-Green Chili Salsa
# 4          16.98                           Chicken Bowl
# 5          10.98                           Chicken Bowl
# 6           1.69                          Side of Chips
# 7          11.75                          Steak Burrito
# 8           9.25                       Steak Soft Tacos
# 9           9.25                          Steak Burrito
# 10          4.45                    Chips and Guacamole
# 11          8.75                   Chicken Crispy Tacos
# 12          8.75                     Chicken Soft Tacos
# 13         11.25                           Chicken Bowl
# 14          4.45                    Chips and Guacamole
# 15          2.39  Chips and Tomatillo-Green Chili Salsa
# ...

# %%
chipo.head(2)
# Out:
#    order_id  quantity                     item_name choice_description  \
# 0         1         1  Chips and Fresh Tomato Salsa                NaN
# 1         1         1                          Izze       [Clementine]
#
#   item_price
# 0      2.39
# 1      3.39

# %%
chipo["item_price"] = chipo["item_price"].astype(float)

# %% [markdown]
# ### Step 5. What is the price of each item?
#
# print a data frame with only two columns `item_name` and `item_price`

# %%
chipo[["item_name", "item_price" ]]
# Out:
#                                   item_name  item_price
# 0              Chips and Fresh Tomato Salsa        2.39
# 1                                      Izze        3.39
# 2                          Nantucket Nectar        3.39
# 3     Chips and Tomatillo-Green Chili Salsa        2.39
# 4                              Chicken Bowl       16.98
# 5                              Chicken Bowl       10.98
# 6                             Side of Chips        1.69
# 7                             Steak Burrito       11.75
# 8                          Steak Soft Tacos        9.25
# 9                             Steak Burrito        9.25
# 10                      Chips and Guacamole        4.45
# 11                     Chicken Crispy Tacos        8.75
# 12                       Chicken Soft Tacos        8.75
# 13                             Chicken Bowl       11.25
# 14                      Chips and Guacamole        4.45
# 15    Chips and Tomatillo-Green Chili Salsa        2.39
# ...

# %% [markdown]
# ### Step 6. Sort by the name of the item

# %%
chipo.sort_values(by = "item_name")
# Out:
#       order_id  quantity          item_name  \
# 3389      1360         2  6 Pack Soft Drink
# 341        148         1  6 Pack Soft Drink
# 1849       749         1  6 Pack Soft Drink
# 1860       754         1  6 Pack Soft Drink
# 2713      1076         1  6 Pack Soft Drink
# 3422      1373         1  6 Pack Soft Drink
# 553        230         1  6 Pack Soft Drink
# 1916       774         1  6 Pack Soft Drink
# 1922       776         1  6 Pack Soft Drink
# 1937       784         1  6 Pack Soft Drink
# 3836      1537         1  6 Pack Soft Drink
# 298        129         1  6 Pack Soft Drink
# 1976       798         1  6 Pack Soft Drink
# 1167       481         1  6 Pack Soft Drink
# 3875      1554         1  6 Pack Soft Drink
# 1124       465         1  6 Pack Soft Drink
# 3886      1558         1  6 Pack Soft Drink
# 2108       849         1  6 Pack Soft Drink
# 3010      1196         1  6 Pack Soft Drink
# 4535      1803         1  6 Pack Soft Drink
# ...

# %% [markdown]
# ### Step 7. What was the quantity of the most expensive item ordered?

# %%
chipo["item_price"].max()
# Out:
# 44.25

# %%
result = chipo['quantity'] = 44.25]
# Out:
#   File "<ipython-input-90-5a9d83d80168>", line 1
#     result = chipo['quantity'] = 44.25]
#                                       ^
# SyntaxError: invalid syntax

# %% [markdown]
# ### Step 8. How many times were a Veggie Salad Bowl ordered?

# %%
chipo['item_name'].value_counts()
# Out:
# Chicken Bowl                             726
# Chicken Burrito                          553
# Chips and Guacamole                      479
# Steak Burrito                            368
# Canned Soft Drink                        301
# Steak Bowl                               211
# Chips                                    211
# Bottled Water                            162
# Chicken Soft Tacos                       115
# Chicken Salad Bowl                       110
# Chips and Fresh Tomato Salsa             110
# Canned Soda                              104
# Side of Chips                            101
# Veggie Burrito                            95
# Barbacoa Burrito                          91
# Veggie Bowl                               85
# Carnitas Bowl                             68
# Barbacoa Bowl                             66
# Carnitas Burrito                          59
# Steak Soft Tacos                          55
# 6 Pack Soft Drink                         54
# ...

# %%
chipo_salad = chipo[chipo.item_name == "Veggie Salad Bowl"]

len(chipo_salad)
# Out:
# 18

# %% [markdown]
# ### Step 9. How many times people orderd more than one Canned Soda?

# %%
Can_soda_count = 

chipo[chipo["quantity"]  > 1]

# %%
chipo[chipo["quantity"]  > 1, where]
# Out:
#       order_id  quantity                              item_name  \
# 4            2         2                           Chicken Bowl
# 18           9         2                            Canned Soda
# 51          23         2                            Canned Soda
# 135         60         2                     Chicken Salad Bowl
# 148         67         2                          Steak Burrito
# 150         68         2                        Chicken Burrito
# 154         70         2                           Chicken Bowl
# 162         73         2                            Canned Soda
# 171         76         2                            Canned Soda
# 213         94         2                     Chicken Salad Bowl
# 217         96         2                   Chicken Crispy Tacos
# 223         98         2                                  Chips
# 235        103         2  Chips and Tomatillo Green Chili Salsa
# 241        105         2                        Chicken Burrito
# ...

# %%
soda_count = chipo[chipo[(['item_name'] == "Canned Soda") & (["quantity"]  > 1)]
# Out:
#   File "<ipython-input-96-4d29514ece72>", line 1
#     soda_count = chipo[chipo[(['item_name'] == "Canned Soda") & (["quantity"]  > 1)]
#                                                                                     ^
# SyntaxError: unexpected EOF while parsing

# %%
count_soda = chipo[(['item_name'] == "Canned Soda") & (["quantity" ] > 1)]]
# Out:
#   File "<ipython-input-99-efe4a7ca8854>", line 1
#     count_soda = chipo[(['item_name'] == "Canned Soda") & (["quantity" ] > 1)]]
#                                                                               ^
# SyntaxError: invalid syntax

# %%
soda_count = chipo[(chipo['item_name'] == "Canned Soda") & (chipo["quantity"]  > 1)]

ilterinfDataframe = dfObj[(dfObj['Sale'] > 30) & (dfObj['Sale'] < 33)
# Out:
#   File "<ipython-input-100-1776fd1eee97>", line 1
#     soda_count = chipo[(chipo[['item_name'] == "Canned Soda") & (chipo["quantity"]  > 1)]
#                                                             ^
# SyntaxError: invalid syntax

# %%
soda_count = chipo[(chipo['item_name'] == "Canned Soda")] & chipo[(chipo["quantity"]  > 1)] ]
# Out:
#   File "<ipython-input-107-bc655d56c966>", line 1
#     soda_count = chipo[(chipo['item_name'] == "Canned Soda")] & chipo[(chipo["quantity"]  > 1)] ]
#                                                                                                 ^
# SyntaxError: invalid syntax

# %%
filter = chipo['item_name'] == "Canned Soda"

# %%
filter1 = chipo['quantity'] > 1

# %%
test = chipo.where(filter & filter1)

# %%
print(filter1)
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4        True
# 5       False
# 6       False
# 7       False
# 8       False
# 9       False
# 10      False
# 11      False
# 12      False
# 13      False
# 14      False
# 15      False
# 16      False
# 17      False
# 18       True
# 19      False
# 20      False
# 21      False
# 22      False
# 23      False
# 24      False
# 25      False
# 26      False
# 27      False
# 28      False
# 29      False
#         ...
# 4592    False
# 4593    False
# 4594    False
# 4595    False
# 4596    False
# 4597    False
# 4598    False
# 4599    False
# 4600    False
# 4601    False
# 4602    False
# 4603    False
# 4604    False
# 4605    False
# 4606    False
# 4607    False
# 4608    False
# 4609    False
# 4610    False
# 4611    False
# 4612    False
# 4613    False
# 4614    False
# 4615    False
# 4616    False
# 4617    False
# 4618    False
# 4619    False
# 4620    False
# 4621    False
# ...

# %%
test = [chipo['item_name'] == 'Canned Soda']

# %%
test
# Out:
# [0       False
#  1       False
#  2       False
#  3       False
#  4       False
#  5       False
#  6       False
#  7       False
#  8       False
#  9       False
#  10      False
#  11      False
#  12      False
#  13      False
#  14      False
#  15      False
#  16      False
#  17      False
#  18       True
#  19      False
#  20      False
#  21      False
#  22      False
#  23      False
#  24      False
#  25      False
#  26      False
#  27      False
#  28      False
#  29      False
#          ...
#  4592    False
#  4593    False
#  4594    False
#  4595    False
#  4596    False
#  4597    False
#  4598    False
#  4599    False
#  4600    False
#  4601    False
#  4602    False
#  4603    False
#  4604    False
#  4605    False
#  4606    False
#  4607    False
#  4608    False
#  4609    False
#  4610    False
#  4611    False
#  4612    False
#  4613    False
#  4614    False
#  4615    False
#  4616    False
#  4617    False
#  4618    False
# ...

# %%
#test = (chipo['item_name'] == 'Canned Soda') & (chipo["quantity"] > 1)

chipo_drink_steak_bowl = chipo[(chipo.item_name == "Canned Soda") & (chipo.quantity > 1)]
len(chipo_drink_steak_bowl)
# Out:
# 20
